# %% [markdown]
# https://www.perplexity.ai/search/83b26786-5e8e-4cbe-ac68-acf4626be7c8

# %%
import pandas as pd
from pandas import DataFrame
import os

folder_name = '每日各站進出站人數'
folder_abspath = os.path.abspath(folder_name)
allitems:list[str] = os.listdir(folder_abspath)
filenames = [file_name for file_name in allitems if len(file_name) > 12]
#參數越多，function就越靈活
def concatenate()->DataFrame:
    csv_absPath = os.path.join(folder_abspath,filenames[0])
    df = pd.read_csv(csv_absPath)
    site_df = pd.read_csv(os.path.abspath('台鐵車站資訊.csv'))
    df1 = pd.merge(df,site_df,left_on='staCode',right_on='stationCode',how='left')
    df2 = df1.reindex(columns=['trnOpDate','staCode','gateInComingCnt','gateOutGoingCnt','name','stationAddrTw','gps','haveBike'])
    df3 = df2.rename(columns={'trnOpDate':'日期',
                    'staCode':'代碼',
                    'gateInComingCnt':'進站人數',
                    'gateOutGoingCnt':'出站人數',
                    'name':'站名',
                    'stationAddrTw':'地址',
                    'gps':'gps',
                    'haveBike':'youBike'
                    })
    df4 = df3.dropna()
    df4['日期'] = pd.to_datetime(df4['日期'].astype(str))
    return df4

# %%
concatenate() #numpy合併用法
# Out:
#               日期    代碼  進站人數  出站人數   站名  \
# 0     2021-01-01   900  7223  7425   基隆
# 1     2021-01-01   910   972  1100   三坑
# 2     2021-01-01   920  1505  1698   八堵
# 3     2021-01-01   930  4385  4657   七堵
# 4     2021-01-01   940  1785  1967   百福
# ...          ...   ...   ...   ...  ...
# 86534 2021-12-31  7360  4062  4451   瑞芳
# 86535 2021-12-31  7361    87   104  海科館
# 86536 2021-12-31  7362   341   403  八斗子
# 86537 2021-12-31  7380   534   481  四腳亭
# 86538 2021-12-31  7390   383   389   暖暖
#
#                                                   地址                 gps  \
# 0                                        基隆市仁愛區港西街5號  25.13411 121.73997
# 1                                 基隆市仁愛區德厚里龍安街 206 號  25.12305 121.74202
# 2                                 基隆市暖暖區八南里八堵路 142 號  25.10843 121.72898
# 3                                   基隆市七堵區長興里東新街 2 號  25.09294 121.71415
# 4                              基隆市七堵區堵南里明德三路 1 之 1 號  25.07795 121.69379
# ...                                              ...                 ...
# 86534                            新北市瑞芳區龍潭里明燈路三段 82 號  25.10861 121.80596
# 86535                                      基隆市中正區長潭里  25.13754 121.79997
# 86536  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)  25.13545 121.80261
# 86537                              新北市瑞芳區吉慶里中央路 65 號  25.10283 121.76192
# 86538                              基隆市暖暖區暖暖里暖暖街 51 號  25.10224 121.74048
#
#       youBike
# 0           Y
# 1           Y
# 2           Y
# 3           Y
# 4           N
# ...       ...
# 86534       Y
# 86535       N
# 86536       N
# 86537       N
# 86538       N
#
# [86539 rows x 8 columns]

# %%
import pandas as pd
from pandas import DataFrame
import os


#參數愈多,function就愈靈活
def concatenate(folder_abspath:str,filename:str)->DataFrame:
    """
    可以組合台鐵進出站的資訊
    param:
        folder_abspath:"所在資料夾的絕對位置"
        filename:"檔案名稱"
    return:
        傳出DataFrame
    """

    csv_absPath = os.path.join(folder_abspath,filename)
    df = pd.read_csv(csv_absPath)
    site_df = pd.read_csv(os.path.abspath('台鐵車站資訊.csv'))
    df1 = pd.merge(df,site_df,left_on='staCode',right_on='stationCode',how='left')
    df2 = df1.reindex(columns=['trnOpDate','staCode','gateInComingCnt','gateOutGoingCnt','name','stationAddrTw','gps','haveBike'])
    df3 = df2.rename(columns={'trnOpDate':'日期',
                    'staCode':'代碼',
                    'gateInComingCnt':'進站人數',
                    'gateOutGoingCnt':'出站人數',
                    'name':'站名',
                    'stationAddrTw':'地址',
                    'gps':'gps',
                    'haveBike':'youBike'
                    })
    df4 = df3.dropna()
    df4['日期'] = pd.to_datetime(df4['日期'].astype(str))
    return df4

# %%
folder_name = '每日各站進出站人數'
folder_abspath = os.path.abspath(folder_name)
allitems:list[str] = os.listdir(folder_abspath)
filenames = [file_name for file_name in allitems if len(file_name) > 12]
concatenate(folder_abspath,filenames[2])
# Out:
#               日期    代碼  進站人數  出站人數   站名  \
# 0     2019-04-23   900  8442  7743   基隆
# 1     2019-04-23   910  1394  1348   三坑
# 2     2019-04-23   920  2770  2423   八堵
# 3     2019-04-23   930  6113  6335   七堵
# 4     2019-04-23   940  2680  2726   百福
# ...          ...   ...   ...   ...  ...
# 60124 2019-12-31  7360  5779  5782   瑞芳
# 60125 2019-12-31  7361   146   142  海科館
# 60126 2019-12-31  7362   116   134  八斗子
# 60127 2019-12-31  7380   654   585  四腳亭
# 60128 2019-12-31  7390   448   396   暖暖
#
#                                                   地址                 gps  \
# 0                                        基隆市仁愛區港西街5號  25.13411 121.73997
# 1                                 基隆市仁愛區德厚里龍安街 206 號  25.12305 121.74202
# 2                                 基隆市暖暖區八南里八堵路 142 號  25.10843 121.72898
# 3                                   基隆市七堵區長興里東新街 2 號  25.09294 121.71415
# 4                              基隆市七堵區堵南里明德三路 1 之 1 號  25.07795 121.69379
# ...                                              ...                 ...
# 60124                            新北市瑞芳區龍潭里明燈路三段 82 號  25.10861 121.80596
# 60125                                      基隆市中正區長潭里  25.13754 121.79997
# 60126  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)  25.13545 121.80261
# 60127                              新北市瑞芳區吉慶里中央路 65 號  25.10283 121.76192
# 60128                              基隆市暖暖區暖暖里暖暖街 51 號  25.10224 121.74048
#
#       youBike
# 0           Y
# 1           Y
# 2           Y
# 3           Y
# 4           N
# ...       ...
# 60124       Y
# 60125       N
# 60126       N
# 60127       N
# 60128       N
#
# [60129 rows x 8 columns]

# %%
folder_name = '每日各站進出站人數'
folder_abspath = os.path.abspath(folder_name)
allitems:list[str] = os.listdir(folder_abspath)
filenames = [file_name for file_name in allitems if len(file_name) > 12]
all_data:list[DataFrame] = [concatenate(folder_abspath,filename) for filename in filenames]
combine_datas = pd.concat(all_data,ignore_index=True)
combine_datas
# Out:
#                日期    代碼  進站人數  出站人數   站名  \
# 0      2021-01-01   900  7223  7425   基隆
# 1      2021-01-01   910   972  1100   三坑
# 2      2021-01-01   920  1505  1698   八堵
# 3      2021-01-01   930  4385  4657   七堵
# 4      2021-01-01   940  1785  1967   百福
# ...           ...   ...   ...   ...  ...
# 406756 2023-12-31  7360  7916  8252   瑞芳
# 406757 2023-12-31  7361   164   195  海科館
# 406758 2023-12-31  7362   652   720  八斗子
# 406759 2023-12-31  7380  1526   656  四腳亭
# 406760 2023-12-31  7390   576   447   暖暖
#
#                                                    地址                 gps  \
# 0                                         基隆市仁愛區港西街5號  25.13411 121.73997
# 1                                  基隆市仁愛區德厚里龍安街 206 號  25.12305 121.74202
# 2                                  基隆市暖暖區八南里八堵路 142 號  25.10843 121.72898
# 3                                    基隆市七堵區長興里東新街 2 號  25.09294 121.71415
# 4                               基隆市七堵區堵南里明德三路 1 之 1 號  25.07795 121.69379
# ...                                               ...                 ...
# 406756                            新北市瑞芳區龍潭里明燈路三段 82 號  25.10861 121.80596
# 406757                                      基隆市中正區長潭里  25.13754 121.79997
# 406758  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)  25.13545 121.80261
# 406759                              新北市瑞芳區吉慶里中央路 65 號  25.10283 121.76192
# 406760                              基隆市暖暖區暖暖里暖暖街 51 號  25.10224 121.74048
#
#        youBike
# 0            Y
# 1            Y
# 2            Y
# 3            Y
# 4            N
# ...        ...
# 406756       Y
# 406757       N
# 406758       N
# 406759       N
# 406760       N
#
# [406761 rows x 8 columns]

# %%
folder_name = '每日各站進出站人數'
folder_abspath = os.path.abspath(folder_name)
allitems:list[str] = os.listdir(folder_abspath)
filenames = [file_name for file_name in allitems if len(file_name) > 12]
all_data:list[DataFrame] = [concatenate(folder_abspath,filename) for filename in filenames]
combine_datas = pd.concat(all_data,ignore_index=True)
combine_datas
# Out:
#                日期    代碼  進站人數  出站人數   站名  \
# 0      2021-01-01   900  7223  7425   基隆
# 1      2021-01-01   910   972  1100   三坑
# 2      2021-01-01   920  1505  1698   八堵
# 3      2021-01-01   930  4385  4657   七堵
# 4      2021-01-01   940  1785  1967   百福
# ...           ...   ...   ...   ...  ...
# 406756 2023-12-31  7360  7916  8252   瑞芳
# 406757 2023-12-31  7361   164   195  海科館
# 406758 2023-12-31  7362   652   720  八斗子
# 406759 2023-12-31  7380  1526   656  四腳亭
# 406760 2023-12-31  7390   576   447   暖暖
#
#                                                    地址                 gps  \
# 0                                         基隆市仁愛區港西街5號  25.13411 121.73997
# 1                                  基隆市仁愛區德厚里龍安街 206 號  25.12305 121.74202
# 2                                  基隆市暖暖區八南里八堵路 142 號  25.10843 121.72898
# 3                                    基隆市七堵區長興里東新街 2 號  25.09294 121.71415
# 4                               基隆市七堵區堵南里明德三路 1 之 1 號  25.07795 121.69379
# ...                                               ...                 ...
# 406756                            新北市瑞芳區龍潭里明燈路三段 82 號  25.10861 121.80596
# 406757                                      基隆市中正區長潭里  25.13754 121.79997
# 406758  新北市瑞芳區建基路2段121號隔壁 砂子里省道臺 2 線 (與新北市瑞芳區交界處、無站房)  25.13545 121.80261
# 406759                              新北市瑞芳區吉慶里中央路 65 號  25.10283 121.76192
# 406760                              基隆市暖暖區暖暖里暖暖街 51 號  25.10224 121.74048
#
#        youBike
# 0            Y
# 1            Y
# 2            Y
# 3            Y
# 4            N
# ...        ...
# 406756       Y
# 406757       N
# 406758       N
# 406759       N
# 406760       N
#
# [406761 rows x 8 columns]

# %%
sort_datas:DataFrame = combine_datas.sort_values(by='日期')
sort_datas
# Out:
#                日期    代碼   進站人數   出站人數  站名                     地址  \
# 173648 2019-04-23  6100     22     16  東里  花蓮縣富里鄉東里村大莊路 15 之 6 號
# 173623 2019-04-23  5070    533    424  南州      屏東縣南州鄉仁里村仁里路 86 號
# 173624 2019-04-23  5080     15     14  鎮安       屏東縣林邊鄉鎮安村永和路 4 號
# 173625 2019-04-23  5090    368    325  林邊      屏東縣林邊鄉仁和村仁愛路 33 號
# 173626 2019-04-23  5100     95     95  佳冬        屏東縣佳冬鄉六根村復興路21號
# ...           ...   ...    ...    ...  ..                    ...
# 406606 2023-12-31  3350   1229   3101  成功   臺中市烏日區榮泉里中山路三段 550 號
# 406607 2023-12-31  3360  19617  16699  彰化       彰化縣彰化市長樂里三民路 1 號
# 406608 2023-12-31  3370   1864   1532  花壇     彰化縣花壇鄉花壇村中正路 370 號
# 406596 2023-12-31  3250   3517   3091  潭子      臺中市潭子區中山路二段352-1號
# 406760 2023-12-31  7390    576    447  暖暖      基隆市暖暖區暖暖里暖暖街 51 號
#
#                        gps youBike
# 173648  23.27233 121.30425       Y
# 173623  22.49207 120.51174       Y
# 173624  22.45794 120.51151       N
# 173625  22.43141 120.51538       Y
# 173626  22.41416 120.54782       N
# ...                    ...     ...
# 406606  24.11424 120.59021       Y
# 406607  24.08177 120.53854       Y
# 406608  24.08173 120.53833       Y
# 406596  24.21255 120.70584       Y
# 406760  25.10224 121.74048       N
#
# [406761 rows x 8 columns]

# %%
sort_datas:DataFrame = combine_datas.sort_values(by='日期')
sort_datas1:DataFrame = sort_datas.set_index('日期')
sort_datas1
# Out:
#               代碼   進站人數   出站人數  站名                     地址                 gps  \
# 日期
# 2019-04-23  6100     22     16  東里  花蓮縣富里鄉東里村大莊路 15 之 6 號  23.27233 121.30425
# 2019-04-23  5070    533    424  南州      屏東縣南州鄉仁里村仁里路 86 號  22.49207 120.51174
# 2019-04-23  5080     15     14  鎮安       屏東縣林邊鄉鎮安村永和路 4 號  22.45794 120.51151
# 2019-04-23  5090    368    325  林邊      屏東縣林邊鄉仁和村仁愛路 33 號  22.43141 120.51538
# 2019-04-23  5100     95     95  佳冬        屏東縣佳冬鄉六根村復興路21號  22.41416 120.54782
# ...          ...    ...    ...  ..                    ...                 ...
# 2023-12-31  3350   1229   3101  成功   臺中市烏日區榮泉里中山路三段 550 號  24.11424 120.59021
# 2023-12-31  3360  19617  16699  彰化       彰化縣彰化市長樂里三民路 1 號  24.08177 120.53854
# 2023-12-31  3370   1864   1532  花壇     彰化縣花壇鄉花壇村中正路 370 號  24.08173 120.53833
# 2023-12-31  3250   3517   3091  潭子      臺中市潭子區中山路二段352-1號  24.21255 120.70584
# 2023-12-31  7390    576    447  暖暖      基隆市暖暖區暖暖里暖暖街 51 號  25.10224 121.74048
#
#            youBike
# 日期
# 2019-04-23       Y
# 2019-04-23       Y
# 2019-04-23       N
# 2019-04-23       Y
# 2019-04-23       N
# ...            ...
# 2023-12-31       Y
# 2023-12-31       Y
# 2023-12-31       Y
# 2023-12-31       Y
# 2023-12-31       N
#
# [406761 rows x 7 columns]

# %%
sort_datas1.info()

# %% [markdown]
# ### 可以把sort_datas1當作是記憶體的資料庫

# %%
sort_datas1.loc['2019-04-23']
sort_datas1.loc['2019-04']
sort_datas1.loc['2019']
sort_datas1.loc['2019-04-23':'2019-04-25']
sort_datas1.loc['2019-04':'2019-05']
# Out:
#               代碼   進站人數   出站人數  站名                       地址  \
# 日期
# 2019-04-23  6100     22     16  東里    花蓮縣富里鄉東里村大莊路 15 之 6 號
# 2019-04-23  5070    533    424  南州        屏東縣南州鄉仁里村仁里路 86 號
# 2019-04-23  5080     15     14  鎮安         屏東縣林邊鄉鎮安村永和路 4 號
# 2019-04-23  5090    368    325  林邊        屏東縣林邊鄉仁和村仁愛路 33 號
# 2019-04-23  5100     95     95  佳冬          屏東縣佳冬鄉六根村復興路21號
# ...          ...    ...    ...  ..                      ...
# 2019-12-31  3300  28209  31140  臺中       臺中市中區綠川里臺灣大道一段 1 號
# 2019-12-31  3290   1209   1030  精武         臺中市東區東南里東光路 161號
# 2019-12-31  3280   3047   2824  太原       臺中市北屯區北興里東光路 665 號
# 2019-12-31  3270   1137   1076  松竹  臺中市北屯區舊社里松竹路一段1473巷100號
# 2019-12-31  3310   1471   1465  五權          臺中市南區建國南路二段201號
#
#                            gps youBike
# 日期
# 2019-04-23  23.27233 121.30425       Y
# 2019-04-23  22.49207 120.51174       Y
# 2019-04-23  22.45794 120.51151       N
# 2019-04-23  22.43141 120.51538       Y
# 2019-04-23  22.41416 120.54782       N
# ...                        ...     ...
# 2019-12-31  24.13747 120.68691       Y
# 2019-12-31  24.14928 120.69777       Y
# 2019-12-31  24.16449 120.69988       Y
# 2019-12-31  24.18045 120.70197       Y
# 2019-12-31  24.12892 120.66657       Y
#
# [60129 rows x 7 columns]

# %%
sort_datas1.loc['2019-05'].query('站名=="頭家厝"')
# Out:
#               代碼  進站人數  出站人數   站名               地址                 gps youBike
# 日期
# 2019-05-01  3260   349   364  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-02  3260   368   374  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-03  3260   447   552  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-04  3260   505   485  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-05  3260   495   471  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-06  3260   449   378  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-07  3260   342   359  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-08  3260   371   396  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-09  3260   380   393  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-10  3260   431   608  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-11  3260   506   487  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-12  3260   607   484  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-13  3260   484   418  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-14  3260   389   394  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-15  3260   367   392  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-16  3260   392   418  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-17  3260   471   570  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-18  3260   480   484  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-19  3260   492   446  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-20  3260   418   366  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-21  3260   384   395  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-22  3260   413   437  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-23  3260   411   415  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-24  3260   479   590  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-25  3260   466   457  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-26  3260   560   483  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-27  3260   418   388  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-28  3260   392   379  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-29  3260   395   389  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-30  3260   381   426  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
# 2019-05-31  3260   445   544  頭家厝  臺中市潭子區頭張東路43巷8號  24.19572 120.70398       N
