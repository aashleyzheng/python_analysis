# %% [markdown]
# https://www.perplexity.ai/search/cea283c5-8750-41ff-8811-20ec42b77262

# %%
import requests
from requests import ConnectionError,HTTPError,Timeout
import numpy as np
import pandas as pd

url = 'https://data.ntpc.gov.tw/api/datasets/010e5b15-3823-4b20-b401-b1cf000550c5/json?page=0&size=1000'
try:
    response = requests.get(url)    
    response.raise_for_status()    
except ConnectionError:
    print('找不到伺服器')
except HTTPError:
    print('網頁找不到')
except Timeout:
    print('超過時間沒有回應')
else:
    print('沒有發生問題')

records = response.json()
#records
allRecords = pd.DataFrame(records,columns=['sna','tot','mday','sbi','sarea','ar','bemp'])
allRecords1 = allRecords.rename(columns= {'sna':'站名', 'sarea':'區域', 'ar':'地址', 'tot':'數量','sbi':'可借', 'bemp':'可還','mday':'時間'})
# Out:
# 沒有發生問題

# %%
allRecords1['站名'].apply(lambda name:name[11:])
# Out:
# 0             下庄市場
# 1           八里行政中心
# 2       八里中庄市場綜合大樓
# 3             大崁國小
# 4            龍形停車場
#           ...
# 995          深坑松柏街
# 996    深坑區公所(深坑老街)
# 997         東南科技大學
# 998          深坑雲鄉路
# 999        埔新街61巷口
# Name: 站名, Length: 1000, dtype: object

# %%
allRecords1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站名      1000 non-null   object
#  1   數量      1000 non-null   object
#  2   時間      1000 non-null   object
#  3   可借      1000 non-null   object
#  4   區域      1000 non-null   object
#  5   地址      1000 non-null   object
#  6   可還      1000 non-null   object
# dtypes: object(7)
# memory usage: 54.8+ KB

# %%
allRecords1['時間'] = pd.to_datetime(allRecords1['時間'])

# %%
allRecords1[['數量','可借','可還']] = allRecords1[['數量','可借','可還']].astype(int)

# %%
allRecords1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站名      1000 non-null   object
#  1   數量      1000 non-null   int64
#  2   時間      1000 non-null   datetime64[ns]
#  3   可借      1000 non-null   int64
#  4   區域      1000 non-null   object
#  5   地址      1000 non-null   object
#  6   可還      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
import numpy as np
grouped = allRecords1.groupby('區域')
agg_df = grouped[['數量','可借','可還']].agg([("加總","sum"),("平均","mean"),("中間數","median"),("最多","max"),("最少","min")])

# %%
agg_df
# Out:
#        數量                             可借                           可還  \
#        加總         平均   中間數  最多  最少    加總         平均  中間數  最多 最少    加總
# 區域
# 三峽區  1540  22.318841  20.0  63  10   675   9.782609  9.0  30  1   865
# 三芝區   170  21.250000  16.0  48  14    47   5.875000  5.5  14  2   123
# 三重區  3774  30.435484  28.5  95  11  1333  10.750000  9.0  83  0  2362
# 中和區  3483  33.490385  30.0  99  10  1361  13.086538  9.0  86  0  2084
# 五股區   667  22.233333  20.0  48  13   224   7.466667  7.5  18  0   441
# 八里區   533  21.320000  20.0  46  13   116   4.640000  3.0  22  0   414
# 土城區  2828  32.136364  30.0  94   9   746   8.477273  6.0  47  0  2000
# 坪林區    65  21.666667  22.0  23  20     6   2.000000  2.0   3  1    59
# 平溪區   174  34.800000  30.0  55  20    29   5.800000  7.0   8  1   145
# 板橋區  7366  36.107843  34.0  99   9  2171  10.642157  6.5  82  0  4974
# 林口區  2233  26.583333  23.5  99  10   833   9.916667  9.0  45  0  1387
# 永和區  1548  28.145455  23.0  79  10   462   8.400000  5.0  39  0  1048
# 汐止區  2397  32.391892  28.5  99   9   991  13.391892  9.0  75  0  1373
# 泰山區   668  26.720000  22.0  45  12   215   8.600000  7.0  23  0   450
# 淡水區  2073  25.912500  21.0  98  10   658   8.225000  6.0  31  0  1395
# 深坑區   109  21.800000  18.0  34  12    16   3.200000  3.0   5  2    93
# 烏來區    28  28.000000  28.0  28  28     4   4.000000  4.0   4  4    24
# 石碇區    52  17.333333  15.0  23  14    18   6.000000  8.0   9  1    34
# 石門區   102  34.000000  26.0  56  20    15   5.000000  6.0   7  2    87
# 貢寮區    60  20.000000  20.0  20  20    19   6.333333  4.0  13  2    41
# 金山區   163  23.285714  24.0  30  15    39   5.571429  6.0   9  2   124
#
#
#             平均   中間數  最多  最少
# 區域
# 三峽區  12.536232  10.0  40   0
# 三芝區  15.375000  14.0  45   0
# 三重區  19.048387  16.0  71   0
# 中和區  20.038462  17.0  56   1
# 五股區  14.700000  12.5  45   6
# 八里區  16.560000  14.0  42   9
# 土城區  22.727273  20.0  62   1
# 坪林區  19.666667  20.0  22  17
# 平溪區  29.000000  29.0  50  12
# 板橋區  24.382353  22.0  86   0
# 林口區  16.511905  14.0  94   3
# 永和區  19.054545  14.0  61   0
# 汐止區  18.554054  15.0  73   0
# 泰山區  18.000000  15.0  40   2
# 淡水區  17.437500  15.5  67   2
# 深坑區  18.600000  16.0  31  10
# 烏來區  24.000000  24.0  24  24
# 石碇區  11.333333  14.0  14   6
# 石門區  29.000000  20.0  54  13
# 貢寮區  13.666667  16.0  18   7
# 金山區  17.714286  15.0  28   9

# %%
agg_df.columns.names = ["租借","統計"]
s1 = agg_df.stack(level=["租借","統計"],future_stack=True)
s1
# Out:
# 區域   租借  統計
# 三峽區  數量  加總     1540.000000
#          平均       22.318841
#          中間數      20.000000
#          最多       63.000000
#          最少       10.000000
#                    ...
# 金山區  可還  加總      124.000000
#          平均       17.714286
#          中間數      15.000000
#          最多       28.000000
#          最少        9.000000
# Length: 315, dtype: float64

# %%
s1.unstack(level="區域")
# Out:
# 區域              三峽區      三芝區          三重區          中和區         五股區     八里區  \
# 租借 統計
# 數量 加總   1540.000000  170.000  3774.000000  3483.000000  667.000000  533.00
#    平均     22.318841   21.250    30.435484    33.490385   22.233333   21.32
#    中間數    20.000000   16.000    28.500000    30.000000   20.000000   20.00
#    最多     63.000000   48.000    95.000000    99.000000   48.000000   46.00
#    最少     10.000000   14.000    11.000000    10.000000   13.000000   13.00
# 可借 加總    675.000000   47.000  1333.000000  1361.000000  224.000000  116.00
#    平均      9.782609    5.875    10.750000    13.086538    7.466667    4.64
#    中間數     9.000000    5.500     9.000000     9.000000    7.500000    3.00
#    最多     30.000000   14.000    83.000000    86.000000   18.000000   22.00
#    最少      1.000000    2.000     0.000000     0.000000    0.000000    0.00
# 可還 加總    865.000000  123.000  2362.000000  2084.000000  441.000000  414.00
#    平均     12.536232   15.375    19.048387    20.038462   14.700000   16.56
#    中間數    10.000000   14.000    16.000000    17.000000   12.500000   14.00
#    最多     40.000000   45.000    71.000000    56.000000   45.000000   42.00
#    最少      0.000000    0.000     0.000000     1.000000    6.000000    9.00
#
# 區域              土城區        坪林區    平溪區          板橋區  ...          永和區  \
# 租借 統計                                               ...
# 數量 加總   2828.000000  65.000000  174.0  7366.000000  ...  1548.000000
#    平均     32.136364  21.666667   34.8    36.107843  ...    28.145455
#    中間數    30.000000  22.000000   30.0    34.000000  ...    23.000000
#    最多     94.000000  23.000000   55.0    99.000000  ...    79.000000
#    最少      9.000000  20.000000   20.0     9.000000  ...    10.000000
# 可借 加總    746.000000   6.000000   29.0  2171.000000  ...   462.000000
#    平均      8.477273   2.000000    5.8    10.642157  ...     8.400000
#    中間數     6.000000   2.000000    7.0     6.500000  ...     5.000000
#    最多     47.000000   3.000000    8.0    82.000000  ...    39.000000
#    最少      0.000000   1.000000    1.0     0.000000  ...     0.000000
# 可還 加總   2000.000000  59.000000  145.0  4974.000000  ...  1048.000000
#    平均     22.727273  19.666667   29.0    24.382353  ...    19.054545
#    中間數    20.000000  20.000000   29.0    22.000000  ...    14.000000
#    最多     62.000000  22.000000   50.0    86.000000  ...    61.000000
#    最少      1.000000  17.000000   12.0     0.000000  ...     0.000000
#
# 區域              汐止區     泰山區        淡水區    深坑區   烏來區        石碇區    石門區  \
# 租借 統計
# 數量 加總   2397.000000  668.00  2073.0000  109.0  28.0  52.000000  102.0
#    平均     32.391892   26.72    25.9125   21.8  28.0  17.333333   34.0
#    中間數    28.500000   22.00    21.0000   18.0  28.0  15.000000   26.0
#    最多     99.000000   45.00    98.0000   34.0  28.0  23.000000   56.0
#    最少      9.000000   12.00    10.0000   12.0  28.0  14.000000   20.0
# 可借 加總    991.000000  215.00   658.0000   16.0   4.0  18.000000   15.0
#    平均     13.391892    8.60     8.2250    3.2   4.0   6.000000    5.0
#    中間數     9.000000    7.00     6.0000    3.0   4.0   8.000000    6.0
#    最多     75.000000   23.00    31.0000    5.0   4.0   9.000000    7.0
#    最少      0.000000    0.00     0.0000    2.0   4.0   1.000000    2.0
# 可還 加總   1373.000000  450.00  1395.0000   93.0  24.0  34.000000   87.0
#    平均     18.554054   18.00    17.4375   18.6  24.0  11.333333   29.0
#    中間數    15.000000   15.00    15.5000   16.0  24.0  14.000000   20.0
#    最多     73.000000   40.00    67.0000   31.0  24.0  14.000000   54.0
#    最少      0.000000    2.00     2.0000   10.0  24.0   6.000000   13.0
#
# 區域            貢寮區         金山區
# 租借 統計
# 數量 加總   60.000000  163.000000
#    平均   20.000000   23.285714
#    中間數  20.000000   24.000000
#    最多   20.000000   30.000000
#    最少   20.000000   15.000000
# 可借 加總   19.000000   39.000000
#    平均    6.333333    5.571429
#    中間數   4.000000    6.000000
#    最多   13.000000    9.000000
#    最少    2.000000    2.000000
# 可還 加總   41.000000  124.000000
#    平均   13.666667   17.714286
#    中間數  16.000000   15.000000
#    最多   18.000000   28.000000
#    最少    7.000000    9.000000
#
# [15 rows x 21 columns]
